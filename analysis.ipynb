# %%
import pandas as pd
import numpy as np
import os
import glob
import xml.etree.ElementTree as ET
import csv

# %% [markdown]
# Segment into pre-data and post-data

# %% [markdown]
# #### Importing XML files

# %%
def import_excel_xml_data_from_folder(folder_path):
    """
    Import Excel 2003 XML (SpreadsheetML) data from all .xml files in a folder
    into one consolidated DataFrame.
    """
    xml_files = glob.glob(os.path.join(folder_path, "*.xml"))
    if not xml_files:
        raise FileNotFoundError(f"No XML files found in {folder_path!r}")
    dfs = []
    # Namespace for SpreadsheetML
    ns = {'ss': 'urn:schemas-microsoft-com:office:spreadsheet'}
    for file_path in xml_files:
        tree = ET.parse(file_path)
        root = tree.getroot()
        # Locate the Table element
        table = root.find(".//ss:Table", ns)
        if table is None:
            print(f"  → no <Table> found in {file_path}, skipping.")
            continue
        rows = table.findall("ss:Row", ns)
        if not rows:
            print(f"  → no <Row> entries in {file_path}, skipping.")
            continue
        # 1) Extract headers from the first row
        header_cells = rows[0].findall("ss:Cell", ns)
        headers = [
            cell.find("ss:Data", ns).text 
            for cell in header_cells
        ]
        # 2) Extract every subsequent row
        data = []
        for row in rows[1:]:
            cells = row.findall("ss:Cell", ns)
            row_vals = []
            for i in range(len(headers)):
                try:
                    data_elem = cells[i].find("ss:Data", ns)
                    row_vals.append(data_elem.text if data_elem is not None else None)
                except IndexError:
                    row_vals.append(None)
            data.append(row_vals)
        df = pd.DataFrame(data, columns=headers)
        df['source_file'] = os.path.basename(file_path)
        dfs.append(df)
        print(f"  → imported {df.shape[0]} rows from {os.path.basename(file_path)}")
    if not dfs:
        raise ValueError("No data was successfully imported from any file.")
    combined = pd.concat(dfs, ignore_index=True)
    print(f"Combined DataFrame: {combined.shape[0]} rows × {combined.shape[1]} columns")
    return combined

# %%
amb_folder = 'AMB'
amb_df = import_excel_xml_data_from_folder(amb_folder)
amb_df.to_parquet('amb_data.parquet')
# Out:
#   → imported 64380 rows from SignalDownload_23-12-December.xml
#   → imported 63635 rows from SignalDownload_24-01-January.xml
#   → imported 66281 rows from SignalDownload_24-02-February.xml
#   → imported 69387 rows from SignalDownload_24-03-March.xml
#   → imported 66775 rows from SignalDownload_24-04-April.xml
#   → imported 67195 rows from SignalDownload_24-05-May.xml
#   → imported 66412 rows from SignalDownload_24-06-June.xml
#   → imported 65723 rows from SignalDownload_24-07-July.xml
#   → imported 70478 rows from SignalDownload_24-08-August.xml
#   → imported 71733 rows from SignalDownload_24-09-September.xml
#   → imported 70172 rows from SignalDownload_24-10-October.xml
#   → imported 73078 rows from SignalDownload_24-11-November.xml
#   → imported 68910 rows from SignalDownload_24-12-December.xml
#   → imported 68465 rows from SignalDownload_25-01-January.xml
#   → imported 68573 rows from SignalDownload_25-02-February.xml
#   → imported 72923 rows from SignalDownload_25-03-March.xml
#   → imported 70545 rows from SignalDownload_25-04-April.xml
#   → imported 73347 rows from SignalDownload_25-05-May.xml
# Combined DataFrame: 1238012 rows × 16 columns

# %%
ip_folder = 'IP'
ip_df = import_excel_xml_data_from_folder(ip_folder)
ip_df.to_parquet('ip_data.parquet')
# Out:
#   → imported 89980 rows from SignalDownload_23-12-December.xml
#   → imported 84156 rows from SignalDownload_24-01-January.xml
#   → imported 87684 rows from SignalDownload_24-02-February.xml
#   → imported 90051 rows from SignalDownload_24-03-March.xml
#   → imported 89880 rows from SignalDownload_24-04-April.xml
#   → imported 91038 rows from SignalDownload_24-05-May.xml
#   → imported 87909 rows from SignalDownload_24-06-June.xml
#   → imported 87340 rows from SignalDownload_24-07-July.xml
#   → imported 96752 rows from SignalDownload_24-08-August.xml
#   → imported 90980 rows from SignalDownload_24-09-September.xml
#   → imported 94046 rows from SignalDownload_24-10-October.xml
#   → imported 102223 rows from SignalDownload_24-11-November.xml
#   → imported 94361 rows from SignalDownload_24-12-December.xml
#   → imported 93510 rows from SignalDownload_25-01-January.xml
#   → imported 94918 rows from SignalDownload_25-02-February.xml
#   → imported 110842 rows from SignalDownload_25-03-March.xml
#   → imported 92043 rows from SignalDownload_25-04-April.xml
#   → imported 109010 rows from SignalDownload_25-05-May.xml
# Combined DataFrame: 1686723 rows × 16 columns

# %% [markdown]
# #### Import previously-saved parquet files

# %%
amb_df = pd.read_parquet('amb_data.parquet')
ip_df = pd.read_parquet('ip_data.parquet')

# %%
amb_df.Value = pd.to_numeric(amb_df.Value)
ip_df.Value = pd.to_numeric(ip_df.Value)

# %% [markdown]
# Limit to users related to a particular optimization

# %%
#list of all providers
ip_provs = ip_df['Clinician Name'].drop_duplicates().sort_values()

with open('ip_provs.csv', 'w', newline='') as file:
    # Don't use csv.writer since we want to manually format each line
    for item in list(set(ip_provs)):
        # Format each line with quotes around the item and a comma at the end
        file.write(f'"{item}",\n')

# %%
prov = ip_df[ip_df['User Type'] != 'Residents and Fellows'][['Clinician Name','Login Department', 'Specialty', 'User Type']].drop_duplicates()
prov
# Out:
#                            Clinician Name        Login Department  \
# 0        Dassinger, Melvin Sidney III, MD           NW SURGERY CL
# 174                     Agarwal, Amit, MD        ACH PULMONARY CL
# 385                Albert, Gregory W., MD     ACH NEUROSURGERY CL
# 565              Angtuaco, Michael J., MD       ACH CARDIOLOGY CL
# 761                    Appell, Lauren, MD  ACH BONE MARROW TRANSP
# ...                                   ...                     ...
# 1540741            Schmitz, Michael L, MD      ACH ANESTHESIOLOGY
# 1544288               Garcia, Xiomara, MD    ACH HEART TRANSPLANT
# 1544989             Thompson, Tonya M, MD           ACH EMERGENCY
# 1553708              Goodman, Allyson, MD            NW EMERGENCY
# 1559779        Hammo, Abdel-Hai Hasan, MD            NW EMERGENCY
#
#                        Specialty  User Type
# 0                General Surgery  Physician
# 174        Pediatric Pulmonology  Physician
# 385                 Neurosurgery  Physician
# 565                   Cardiology  Physician
# 761      Hematology and Oncology  Physician
# ...                          ...        ...
# 1540741           Anesthesiology  Physician
# 1544288               Transplant  Physician
# 1544989                 Sedation  Physician
# 1553708       Emergency Medicine  Physician
# 1559779         Gastroenterology  Physician
#
# [671 rows x 4 columns]

# %%
hosp = prov[
    ((prov['Login Department'] == 'ACH IP HOSPITALIST') | (prov['Clinician Name'].str.contains('Bolden')) | (prov['Clinician Name'].str.contains('Barkley')) | (prov['Clinician Name'].str.contains('Tilly'))) 
    &
    (prov['User Type'] != 'APP') 
    &
    ~((prov['Clinician Name'].str.contains('Farrar')) | (prov['Clinician Name'].str.contains('Barr')) | (prov['Clinician Name'].str.contains('Latch')) | (prov['Clinician Name'].str.contains('Nguyen')))
].sort_values(by='Clinician Name')

# %%
hosp
# Out:
#                      Clinician Name     Login Department          Specialty  \
# 27938            Alkhatib, Lynn, MD   ACH IP HOSPITALIST         Pediatrics
# 37741         Barkley, Hannah G, MD  ACH COF TEACHING CL         Pediatrics
# 8196            Barnes, Emily S, MD   ACH IP HOSPITALIST         Pediatrics
# 24938          Barnes, Sarah A., MD   ACH IP HOSPITALIST         Pediatrics
# 70613         Bolden, Branson B, MD   ACH AFTER HOURS CL  Internal Medicine
# 40658            Cantu, Rebecca, MD   ACH IP HOSPITALIST         Pediatrics
# 34444             Cook, Devin W, DO   ACH IP HOSPITALIST         Pediatrics
# 34159      Dailey, Raymond Lane, MD   ACH IP HOSPITALIST         Pediatrics
# 66621            Ekdahl, Rachel, MD   ACH IP HOSPITALIST         Pediatrics
# 45010          Filipek, Jacob F, MD   ACH IP HOSPITALIST         Pediatrics
# 47404       Fisher, Charalene R, MD   ACH IP HOSPITALIST         Pediatrics
# 982280           Flaherty, Ryan, DO   ACH IP HOSPITALIST         Pediatrics
# 70974       Jeffries, Kristyn N, MD   ACH IP HOSPITALIST  Internal Medicine
# 3598              Liu, Daniel S, MD   ACH IP HOSPITALIST         Pediatrics
# 142491       McKee, Steven Greg, MD   ACH IP HOSPITALIST         Pediatrics
# 34559      Rodriquez, Carissa T, MD   ACH IP HOSPITALIST         Pediatrics
# 6237            Sanders, Sara C, MD   ACH IP HOSPITALIST         Pediatrics
# 59749            Shafi, Obeid M, MD   ACH IP HOSPITALIST         Pediatrics
# 54396        Slagle, Brittany M, DO   ACH IP HOSPITALIST         Pediatrics
# 28754            Smith, Conor H, MD   ACH IP HOSPITALIST         Pediatrics
# 29185       Steele, Ryan Wesley, MD   ACH IP HOSPITALIST         Pediatrics
# 66271         Stinson, Azriel J, DO   ACH IP HOSPITALIST         Pediatrics
# 801902  Tang, Katherine Michele, MD   ACH IP HOSPITALIST         Pediatrics
# 49601           Taylor, Maxwell, MD   ACH IP HOSPITALIST         Pediatrics
# 29056         Tilly, Collette M, MD  ACH COF TEACHING CL         Pediatrics
# 47253         Williford, Dustin, MD   ACH IP HOSPITALIST         Pediatrics
# 47689      Wood-Katz, Melissa A, MD   ACH IP HOSPITALIST         Pediatrics
# 21532          Yarbrough, Linda, MD   ACH IP HOSPITALIST         Pediatrics
#
#         User Type
# 27938   Physician
# 37741   Physician
# 8196    Physician
# 24938   Physician
# 70613   Physician
# 40658   Physician
# 34444   Physician
# 34159   Physician
# 66621   Physician
# 45010   Physician
# 47404   Physician
# 982280  Physician
# 70974   Physician
# 3598    Physician
# 142491  Physician
# 34559   Physician
# 6237    Physician
# 59749   Physician
# 54396   Physician
# 28754   Physician
# 29185   Physician
# 66271   Physician
# 801902  Physician
# 49601   Physician
# 29056   Physician
# 47253   Physician
# 47689   Physician
# 21532   Physician

# %%
#identify list of providers in optmization
inc_provs = list(set(hosp['Clinician Name']))

# %%
#list of all signal metrics
ip_mets = ip_df['Metric'].drop_duplicates().sort_values()
amb_mets = amb_df['Metric'].drop_duplicates().sort_values()

with open('ip_metrics.csv', 'w', newline='') as file:
    # Don't use csv.writer since we want to manually format each line
    for item in list(set(ip_mets)):
        # Format each line with quotes around the item and a comma at the end
        file.write(f'"{item}",\n')

with open('amb_metrics.csv', 'w', newline='') as file:
    # Don't use csv.writer since we want to manually format each line
    for item in list(set(amb_mets)):
        # Format each line with quotes around the item and a comma at the end
        file.write(f'"{item}",\n')

# %%
ip_mets = ip_df['Metric'].drop_duplicates().sort_values()

# %%
#enter list of hypothesized metrics 
hypo_metrics = ['']

# %%
#limit data to those in the optimization group
opt_data_ip = ip_df[ip_df['Clinician Name'].isin(inc_provs)]
opt_data_amb = amb_df[amb_df['Clinician Name'].isin(inc_provs)]

shared_col = ['EMP CID', 'SER CID', 'Clinician Name', 'Clinician Type', 'Specialty', 'User Type',
       'Reporting Period Start Date', 'Reporting Period End Date', 'Metric',
       'Numerator', 'Denominator', 'Value', 'Metric ID', 'source_file']

opt_data = pd.concat([opt_data_ip, opt_data_amb], ignore_index=False)

# %% [markdown]
# Segment into pre-data and post-data

# %% [markdown]
# Before/After comparisons in % differences

# %%
opt_data['Reporting Period Start Date'] = pd.to_datetime(opt_data['Reporting Period Start Date'])
opt_data['Reporting Period End Date'] = pd.to_datetime(opt_data['Reporting Period End Date'])

# %%
opt_data[['Reporting Period Start Date','Reporting Period End Date']].drop_duplicates().sort_values(by='Reporting Period Start Date')
# Out:
#         Reporting Period Start Date Reporting Period End Date
# 3598                     2023-11-26                2023-12-30
# 93695                    2023-12-31                2024-01-27
# 177701                   2024-01-28                2024-02-24
# 268856                   2024-02-25                2024-03-30
# 355944                   2024-03-31                2024-04-27
# 445651                   2024-04-28                2024-05-25
# 536115                   2024-05-26                2024-06-29
# 624170                   2024-06-30                2024-07-27
# 712149                   2024-07-28                2024-08-31
# 808545                   2024-09-01                2024-09-28
# 899868                   2024-09-29                2024-10-26
# 998463                   2024-10-27                2024-11-30
# 1097747                  2024-12-01                2024-12-28
# 1189640                  2024-12-29                2025-01-25
# 1280671                  2025-01-26                2025-02-22
# 1378384                  2025-02-23                2025-03-29
# 1486864                  2025-03-30                2025-04-26

# %%
pre_start = pd.to_datetime('2023-11-26')
pre_end = pd.to_datetime('2024-02-25')
post_start = pd.to_datetime('2024-09-29')
post_end = pd.to_datetime('2024-12-29')

# %%
predata = opt_data[(opt_data['Reporting Period Start Date'] >= pre_start) & (opt_data['Reporting Period Start Date'] <= pre_end)]
predata['Period'] = 'Pre'
postdata = opt_data[(opt_data['Reporting Period Start Date'] >= post_start) & (opt_data['Reporting Period Start Date'] <= post_end)]
postdata['Period'] = 'Post'
# Out:
# /tmp/ipykernel_1155/823114164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predata['Period'] = 'Pre'
# /tmp/ipykernel_1155/823114164.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   postdata['Period'] = 'Post'

# %% [markdown]
# Section level

# %%
predata
# Out:
#          EMP CID   SER CID         Clinician Name Clinician Type  \
# 3598     1705995   1408856      Liu, Daniel S, MD      PHYSICIAN
# 3599     1705995   1408856      Liu, Daniel S, MD      PHYSICIAN
# 3600     1705995   1408856      Liu, Daniel S, MD      PHYSICIAN
# 3601     1705995   1408856      Liu, Daniel S, MD      PHYSICIAN
# 3602     1705995   1408856      Liu, Daniel S, MD      PHYSICIAN
# ...          ...       ...                    ...            ...
# 260257  17015488  17014423  Barkley, Hannah G, MD      PHYSICIAN
# 260258  17015488  17014423  Barkley, Hannah G, MD      PHYSICIAN
# 260259  17015488  17014423  Barkley, Hannah G, MD      PHYSICIAN
# 260260  17015488  17014423  Barkley, Hannah G, MD      PHYSICIAN
# 260261  17015488  17014423  Barkley, Hannah G, MD      PHYSICIAN
#
#        Login Service Area    Login Department   Specialty  User Type  \
# 3598     ACH SERVICE AREA  ACH IP HOSPITALIST  Pediatrics  Physician
# 3599     ACH SERVICE AREA  ACH IP HOSPITALIST  Pediatrics  Physician
# 3600     ACH SERVICE AREA  ACH IP HOSPITALIST  Pediatrics  Physician
# 3601     ACH SERVICE AREA  ACH IP HOSPITALIST  Pediatrics  Physician
# 3602     ACH SERVICE AREA  ACH IP HOSPITALIST  Pediatrics  Physician
# ...                   ...                 ...         ...        ...
# 260257                NaN                 NaN  Pediatrics  Physician
# 260258                NaN                 NaN  Pediatrics  Physician
# 260259                NaN                 NaN  Pediatrics  Physician
# 260260                NaN                 NaN  Pediatrics  Physician
# 260261                NaN                 NaN  Pediatrics  Physician
#
#        Reporting Period Start Date Reporting Period End Date  \
# 3598                    2023-11-26                2023-12-30
# 3599                    2023-11-26                2023-12-30
# 3600                    2023-11-26                2023-12-30
# 3601                    2023-11-26                2023-12-30
# 3602                    2023-11-26                2023-12-30
# ...                            ...                       ...
# 260257                  2024-02-25                2024-03-30
# 260258                  2024-02-25                2024-03-30
# 260259                  2024-02-25                2024-03-30
# 260260                  2024-02-25                2024-03-30
# 260261                  2024-02-25                2024-03-30
#
#                                                   Metric           Numerator  \
# 3598                          (IP) Time in Notes per Day  425.98329299999995
# 3599              (IP) Time in Notes per Patient per Day  425.98329299999995
# 3600               (IP) Note Composition Method - Manual               18231
# 3601    (IP) Note Composition Method - Voice Recognition                 702
# 3602        (IP) Note Composition Method - Transcription                   0
# ...                                                  ...                 ...
# 260257         Secure Chat Messages Sent per Appointment                 660
# 260258                 Secure Chat Patient Conversations                  28
# 260259             Secure Chat Messages Received per Day                1175
# 260260     Secure Chat Messages Received per Appointment                1175
# 260261                              Progress Note Length               39668
#
#        Denominator                 Value Metric ID  \
# 3598            20    21.299164649999998      2119
# 3599           210    2.0284918714285713      2120
# 3600        126150   0.14451843043995244      2121
# 3601        126150  0.005564803804994055      2121
# 3602        126150                     0      2121
# ...            ...                   ...       ...
# 260257           9     73.33333333333333      1153
# 260258          36    0.7777777777777778      1156
# 260259           1                  1175      1249
# 260260           9    130.55555555555554      1250
# 260261           9     4407.555555555556      1252
#
#                               source_file      Service Area  \
# 3598    SignalDownload_23-12-December.xml               NaN
# 3599    SignalDownload_23-12-December.xml               NaN
# 3600    SignalDownload_23-12-December.xml               NaN
# 3601    SignalDownload_23-12-December.xml               NaN
# 3602    SignalDownload_23-12-December.xml               NaN
# ...                                   ...               ...
# 260257     SignalDownload_24-03-March.xml  ACH SERVICE AREA
# 260258     SignalDownload_24-03-March.xml  ACH SERVICE AREA
# 260259     SignalDownload_24-03-March.xml  ACH SERVICE AREA
# 260260     SignalDownload_24-03-March.xml  ACH SERVICE AREA
# 260261     SignalDownload_24-03-March.xml  ACH SERVICE AREA
#
#                  Department Period
# 3598                    NaN    Pre
# 3599                    NaN    Pre
# 3600                    NaN    Pre
# 3601                    NaN    Pre
# 3602                    NaN    Pre
# ...                     ...    ...
# 260257  ACH COF TEACHING CL    Pre
# 260258  ACH COF TEACHING CL    Pre
# 260259  ACH COF TEACHING CL    Pre
# 260260  ACH COF TEACHING CL    Pre
# 260261  ACH COF TEACHING CL    Pre
#
# [16200 rows x 19 columns]

# %%
mets = predata[['Metric', 'Value']].sort_values(by='Metric')

# %%
mets.shape
# Out:
# (16200, 2)

# %%
pre_med = pd.DataFrame(predata[['Metric', 'Value']].groupby('Metric').agg(['median']))
pre_med.columns = ['Pre Med Value']
post_med = pd.DataFrame(postdata[['Metric', 'Value']].groupby('Metric').agg(['median']))
post_med.columns = ['Post Med Value']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2534, in GroupBy.median.<locals>.<lambda>(x)
#    2461 """
#    2462 Compute median of groups, excluding missing values.
#    2463
#    (...)   2530 Freq: MS, dtype: float64
#    2531 """
#    2532 result = self._cython_agg_general(
#    2533     "median",
# -> 2534     alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535     numeric_only=numeric_only,
#    2536 )
#    2537 return result.__finalize__(self.obj, method="groupby")
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)   6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)  12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433     )
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#
# TypeError: Cannot convert ['0.17976178571428572' '0.6631943749999999' '0' '0.33599996' '0'
#  '0.06574072222222221' '0' '33.51999913333334' '0.5185184444444445'
#  '0.6106059696969697' '22.731999359999996' '69.2460299047619'
#  '15.208666200000003' '0.04999996551724138' '0.020833333333333332' '0.01'
#  '0' '0' '0.037777733333333334' '0.647619' '0' '0.07592588888888889'
#  '2.8197915625' '8.133333148148148' '0.16111104166666668' '0'
#  '1.1447367368421053' '0.04722216666666667' '1.4517543157894737'
#  '0.009803882352941176' '0.08888887499999999' '0' '2.277777619047619'
#  '1.8044869230769232' '13.103571071428572' '2.6104165416666665'
#  '5.520512653846154' '0' '0.2644443333333334' '0' '0.1088888' '0'
#  '1.366666' '0.11999993333333334' '0.5999997777777778' '0' '0' '0'
#  '12.583333' '0.2151515' '0' '0.6788888' '0.822222111111111' '0'
#  '0.5249998333333333' '0' '0.06666662500000001' '2.409259037037037'
#  '0.461111' '10.385256115384616' '8.732638708333331' '3.608730047619048'
#  '0' '0' '0.017592555555555556' '0.056481444444444445'
#  '0.049999999999999996' '0.6660491851851853' '0.24062493750000002'
#  '0.9685183333333333' '0' '0' '0.2133333' '21.459523285714287' '0.0458333'
#  '0.6203702777777779' '0.6868421052631579' '1.5018516666666666'
#  '0.0810605' '0.015079333333333333' '2.7564100384615386'
#  '1.1472219583333332' '12.47866632' '21.270634285714287'
#  '6.741176294117647' '0' '0' '0.10490188235294118' '0'
#  '0.1618055416666667' '0.31845232142857144' '0' '0' '0' '0'
#  '0.036231869565217394' '15.27638858333333' '0'] to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pre_med = pd.DataFrame(predata[['Metric', 'Value']].groupby('Metric').agg(['median']))
#       2 pre_med.columns = ['Pre Med Value']
#       3 post_med = pd.DataFrame(postdata[['Metric', 'Value']].groupby('Metric').agg(['median']))
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/apply.py:1571, in GroupByApply.agg_or_apply_list_like(self, op_name)
#    1566 # Only set as_index=True on groupby objects, not Window or Resample
#    1567 # that inherit from this class.
#    1568 with com.temp_setattr(
#    1569     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1570 ):
# -> 1571     keys, results = self.compute_list_like(op_name, selected_obj, kwargs)
#    1572 result = self.wrap_results_list_like(keys, results)
#    1573 return result
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/apply.py:385, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     379 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     380 args = (
#     381     [self.axis, *self.args]
#     382     if include_axis(op_name, colg)
#     383     else self.args
#     384 )
# --> 385 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     386 results.append(new_res)
#     387 indices.append(index)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
#     259     # columns is not narrowed by mypy from relabeling flag
#     260     assert columns is not None  # for mypy
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/generic.py:362, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360     for idx, (name, func) in enumerate(arg):
#     361         key = base.OutputKey(label=name, position=idx)
# --> 362         results[key] = self.aggregate(func, *args, **kwargs)
#     364 if any(isinstance(x, DataFrame) for x in results.values()):
#     365     from pandas import concat
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/generic.py:249, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247     if engine_kwargs is not None:
#     248         kwargs["engine_kwargs"] = engine_kwargs
# --> 249     return getattr(self, func)(*args, **kwargs)
#     251 elif isinstance(func, abc.Iterable):
#     252     # Catch instances of lists / tuples
#     253     # but not the class list / tuple itself.
#     254     func = maybe_mangle_lambdas(func)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:2532, in GroupBy.median(self, numeric_only)
#    2459 @final
#    2460 def median(self, numeric_only: bool = False) -> NDFrameT:
#    2461     """
#    2462     Compute median of groups, excluding missing values.
#    2463
#    (...)   2530     Freq: MS, dtype: float64
#    2531     """
# -> 2532     result = self._cython_agg_general(
#    2533         "median",
#    2534         alt=lambda x: Series(x, copy=False).median(numeric_only=numeric_only),
#    2535         numeric_only=numeric_only,
#    2536     )
#    2537     return result.__finalize__(self.obj, method="groupby")
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File /mnt/c/Users/liud/Arkansas Children's/Medical Informatics Office (Arkansas Childrens) - Analytics 2.0/signal-analysis/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->median,dtype->object]

# %%
pre_post = pre_med.join(post_med)

# %%
pre_post

# %%
pre_post['PercentDiff'] = (pre_post['Post Med Value'] - pre_post['Pre Med Value'])/pre_post['Pre Med Value']
pre_post['AbsDiff'] = (pre_post['Post Med Value'] - pre_post['Pre Med Value'])

# %% [markdown]
# Data Driven - Identify percent changes > 5%

# %%
sig_diff = pre_post[(pre_post['PercentDiff'] <= -0.05) | (pre_post['PercentDiff'] >= 0.05)]

# %%
sig_diff_metrics = list(sig_diff.index.drop_duplicates())

# %% [markdown]
# Hypothesis Driven

# %%
pre_post[pre_post.Metric.isin(hypo_metrics)]

# %% [markdown]
# Final Metrics to include in Report
